# %%
import pandas as pd 

df = pd.read_csv("../data/raw/credit_card_frauds.csv")

# first 5 rows
# print("first 5 rows \n")
# print(df.head())

# # last 5 rows
# print("last 5 rows \n")
# print(df.tail())

# # 10 random rows
# print("10 random rows \n")
# print(df.sample(10))

# (rows, cols)
print("dataframe shape \n")
df.shape

# columns: 
# trans_date_trans_time, YYYY-MM-DD & 24 hour time format 00:00:00
# merchant, name of merchant, some are in quotes and some are not
# category, pos = point of service like a cashier or self checkout, others are more broad like "entertainment"
# amt, $ amt of transaction 0.00
# city, city
# state, state
# lat, 000.0000
# long, 000.0000
# city_pop, 
# job, 
# dob, 
# trans_num, 
# merch_lat, 
# merch_long, 
# is_fraud, 0 or 1, 0 = no fraud 1 = fraud
# Out:
# dataframe shape
# (339607, 15)

# %%
import pandas as pd 

df = pd.read_csv("../data/raw/credit_card_frauds.csv")

df.info()         # column names, dtypes, non-null counts — great first call
df.dtypes         # just the types
df.columns        # list of column names
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 339607 entries, 0 to 339606
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   trans_date_trans_time  339607 non-null  str
#  1   merchant               339607 non-null  str
#  2   category               339607 non-null  str
#  3   amt                    339607 non-null  float64
#  4   city                   339607 non-null  str
#  5   state                  339607 non-null  str
#  6   lat                    339607 non-null  float64
#  7   long                   339607 non-null  float64
#  8   city_pop               339607 non-null  int64
#  9   job                    339607 non-null  str
#  10  dob                    339607 non-null  str
#  11  trans_num              339607 non-null  str
#  12  merch_lat              339607 non-null  float64
#  13  merch_long             339607 non-null  float64
# ...

# %%
import pandas as pd 

df = pd.read_csv("../data/raw/credit_card_frauds.csv")

# print(df.isnull().sum())                  # count of nulls per column
# print(df.isnull().mean())                 # proportion of nulls per column (more intuitive)
# print(df[df.isnull().any(axis=1)])        # rows that have any null

x = (df['is_fraud'] == 1).sum()           # fraud count

print(x/len(df))                          # fraud rate

print(df.duplicated().sum())              # number of duplicate rows
# Out:
# 0.005247241664629999
# 0
